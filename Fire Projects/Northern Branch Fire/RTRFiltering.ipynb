# %%
import pandas as pd

# %%
fileName = 'Vehicle Check\cCalRecycle_NorthBranch_DataManagerTicketExport.xlsx'

# %% [markdown]
# # This opens the excell we need. Has columns preselected. Can change this

# %%
df = pd.read_excel(fileName, usecols = ['Zone Name', 'Addr No', 'Addr St', 'Service Code', 'Is Void', 'Unit Count', 'End Time',
                                       'Ticket Number', 'Disposal Monitor Name', 'Ticket Notes'], index_col= "Zone Name") #index_col = "Zone Name"

# %% [markdown]
# # This cell will rearrage our columns in any order we want

# %%
df = df[['Addr No', 'Addr St', 'Service Code', 'Is Void', 'Unit Count', 'End Time',
         'Ticket Number', 'Disposal Monitor Name', 'Ticket Notes']]

# %% [markdown]
# # This will take out all special Chars in RTR service code cells

# %%
spec_chars = ["!",'"',"#","%","&","'","(",")",
              "*","+",",","-",".","/",":",";","<",
              "=",">","?","@","[","\\","]","^","_",
              "`","{","|","}","~","–"]
for char in spec_chars:
    df["Service Code"] = df["Service Code"].str.replace(char, ' ')
    
df["Service Code"] = df["Service Code"].str.split().str.join(" ")

codes = ["CO4", "4"]

df = df[(df["Is Void"] != True) & (df["Service Code"].isin(codes))]

# df.loc["Zone Name"]
df
# Out:
# <ipython-input-5-5fcc71993348>:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Service Code"] = df["Service Code"].str.replace(char, ' ')
#                     Addr No                    Addr St Service Code  Is Void  \
# Zone Name
# 016531280               601       INDIAN MEADOWS DRIVE            4    False
# 009340090               129            SOUTH FORK ROAD            4    False
# 009340090               129            SOUTH FORK ROAD            4    False
# 016531230               501       INDIAN MEADOWS DRIVE            4    False
# 016531230               501      INDIAN MEADOWS DRIVE             4    False
# ...                     ...                        ...          ...      ...
# 016050490               211         LOWER AIRPORT ROAD            4    False
# ...

# %%
df.dtypes #

# %%
df.info() #Shows the rows count and the types

# %%
df.describe() #Shows the main statistics for every numerical column in our dataset

# %%
df.loc["071390004"]
# Out:
#                    Addr No         Addr St Service Code  Is Void  Unit Count  \
# Zone Name
# 071390004  071-390-004-000  GRAYSTONE LANE          CO4    False         2.0
# 071390004  071-390-004-000  GRAYSTONE LANE            4    False         2.0
#
#                             End Time Ticket Number Disposal Monitor Name  \
# Zone Name
# 071390004 2021-05-18 15:20:11.000000     924490150           AZEREA LANE
# 071390004 2021-05-18 15:20:00.000001     628540009           AZEREA LANE
#
#                                                 Ticket Notes
# Zone Name
# 071390004  should have been item 4 but already billed. cr...
# 071390004                                                NaN
