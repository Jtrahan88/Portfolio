# %%
import pandas as pd
import os
import glob
import numpy as np

# %%
#  central
path1 = r"C:\Users\jacque.trahan\Downloads\Central Division 2021 Debris Removal Tracker*"
file_type1 = ".xlsx"
load1 = glob.glob(path1 + file_type1)
df = pd.read_excel(max(load1, key=os.path.getctime), parse_dates=True, keep_default_na=False)

# %%
# south central
path = r"C:\Users\jacque.trahan\Downloads\South Central Division 2021 Debris Removal Tracker*"
load = glob.glob(path + file_type1)
df2 = pd.read_excel(max(load, key=os.path.getctime), parse_dates=True, keep_default_na=False)

# %%
# concat files
df_both = pd.concat([df, df2])

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 983 entries, 0 to 982
# Data columns (total 141 columns):
#  #    Column                                              Dtype
# ---   ------                                              -----
#  0    APN_ROW Segment                                     object
#  1    ROE Type                                            object
#  2    Structural Status                                   object
#  3    Haz Tree Status                                     object
#  4    Debris Crew                                         object
#  5    Tree Crew                                           object
#  6    Street #                                            object
#  7    Street Name                                         object
#  8    Unit #                                              object
#  9    City                                                object
#  10   County                                              object
# ...

# %%
check = df_both.copy()
check =

# %%
fso = df_both.copy()
fso = fso[['APN_ROW Segment', 'Structural Status', 'Street #', 'Street Name','County','Hold', 'Hold Reason',
           'Site Assessment',
           'ASB Assessment', 'ASB Suspected','ASB Results','ASB Abatement', 'CAC Clearance', 
           'Bio Assessment', 'Bio Monitor Needed',
           'Arch Assessment', 'Arch Assessment',
                  'Haz Tree Status',"Tree Removal Complete", # should say TFSW complete willneed to check this
                  'Soil Samples Approved',
                  'Erosion Control Complete', 'Erosion Control Waiver',
                   'FSO Complete', 'FSO Sent to County','Debris Crew',
       ]]

# %% [markdown]
# # Must haves for FSO to be Ready
#
# * SA
# * ASB
# * BIO & ARCH dates or survey during the debris removal
# * If haz trees then Tree completion date
# * Soils Approved
# * ERosion control or wavier date

# %%
fso[(fso['Site Assessment'].notna()) &
    (fso['ASB Assessment'].notna())].to_excel('Test FSO check.xlsx')

# %%
fso['ASB Assessment'] = pd.to_datetime(fso['ASB Assessment'])
fso['ASB Abatement'] = pd.to_datetime(fso['ASB Abatement'])

# %%
fso.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1009 entries, 0 to 25
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   APN_ROW Segment           1009 non-null   object
#  1   Structural Status         1009 non-null   object
#  2   Street #                  1009 non-null   object
#  3   Street Name               1009 non-null   object
#  4   County                    1009 non-null   object
#  5   Hold                      1009 non-null   object
#  6   Hold Reason               1009 non-null   object
#  7   Site Assessment           897 non-null    object
#  8   ASB Assessment            778 non-null    datetime64[ns]
#  9   ASB Suspected             1009 non-null   object
#  10  ASB Results               1009 non-null   object
#  11  ASB Abatement             209 non-null    datetime64[ns]
#  12  CAC Clearance             233 non-null    object
# ...

# %%
fso[(fso['ASB Assessment'] < fso['ASB Abatement'])]
# Out:
#     APN_ROW Segment           Structural Status     Street #  \
# 1       002-230-055   Ready for Tree Operations        17300
# 8    012-036-020_23            Re-scrape Needed        16425
# 9    012-036-020_28     Final Sign Off Complete        16425
# 10   012-036-020_29     Final Sign Off Complete        16425
# 12      041-021-034            Re-scrape Needed  041-021-034
# ..              ...                         ...          ...
# 975     042-376-020          Returned to County        16383
# 977     037-211-004  Debris Removal in Progress         2010
# 978     037-212-001     Ready for Soil Sampling        19826
# 980     041-651-011   Ready for Tree Operations         4897
# 982     041-651-013    Ready for Debris Removal         4915
#
#            Street Name     County  Hold Hold Reason      Site Assessment  \
# 1           Highway 89     Alpine                    2021-10-05 00:00:00
# 8             Dam Road       Lake  True   DTSC Attn  2021-10-19 00:00:00
# ...
